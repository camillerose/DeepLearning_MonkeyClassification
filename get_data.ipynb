# %% [markdown]
# ## Java command to get URLs

# %%
# Download data from google images
# Command+Option+J once on google images search results page to open javascript console
# Run command: 

# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);

# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));

# code from https://github.com/fpingham/google-images-dataset/blob/master/download_images.ipynb

# %% [markdown]
# Upload .csv file of urls to working directory

# %% [markdown]
# ## Create directory and upload URL files to server

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'marmosets'
file = 'urls_marmosets.csv'

# %%
folder = 'tamarins'
file = 'urls_tamarins.csv'

# %%
folder = 'howlers'
file = 'urls_howlers.csv'

# %%
folder = 'capuchins'
file = 'urls_capuchins.csv'

# %%
folder = 'squirrel'
file = 'urls_squirrels.csv'

# %%
folder = 'saki'
file = 'urls_sakis.csv'

# %%
folder = 'woolly'
file = 'urls_woollys.csv'

# %%
folder = 'night'
file = 'urls_night.csv'

# %%
folder = 'spider'
file = 'urls_spiders.csv'

# %%
path = Path('data/new_world_monkeys')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/folder/file, dest, max_pics=25)

# %% [markdown]
# ## View data

# %%
classes = ['marmosets','tamarins','howlers','capuchins','squirrel','saki','woolly','night','howlers','spider']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# marmosets
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>
# tamarins
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00]
#     </div>
# howlers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>
# capuchins
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>
# squirrel
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='24', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24/24 00:00<00:00]
#     </div>
# saki
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>
# woolly
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='24', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24/24 00:00<00:00]
#     </div>
# night
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00]
#     </div>
# howlers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>
# spider
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00]
#     </div>

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=0)

# %%
data.show_batch(rows=4, figsize=(7,8))
